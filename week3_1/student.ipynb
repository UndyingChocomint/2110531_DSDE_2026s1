# %% [markdown]
# ##**Assignment 3 (2024/2): ML1**
# **Safe to eat or deadly poison?**

# %% [markdown]
# This homework is a classification task to identify whether a mushroom is edible or poisonous.
#
# This dataset includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family Mushroom drawn from The Audubon Society Field Guide to North American Mushrooms (1981).
#
# Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended. This latter class was combined with the poisonous one. The Guide clearly states that there is no simple rule for determining the credibility of a mushroom; no rule like "leaflets three, let it be'' for Poisonous Oak and Ivy.

# %% [markdown]
# Step 1. Load 'mushroom2020_dataset.csv' data from the “Attachment” (note: this data set has been preliminarily prepared.).
#
# Step 2. Drop rows where the target (label) variable is missing.
#
# Step 3. Drop the following variables:
# 'id','gill-attachment', 'gill-spacing', 'gill-size','gill-color-rate', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring-rate','stalk-color-below-ring-rate','veil-color-rate','veil-type'
#
# Step 4. Examine the number of rows, the number of digits, and whether any are missing.
#
# Step 5. Fill missing values by adding the mean for numeric variables and the mode for nominal variables.
#
# Step 6. Convert the label variable e (edible) to 1 and p (poisonous) to 0 and check the quantity. class0: class1
#
# Step 7. Convert the nominal variable to numeric using a dummy code with drop_first = True.
#
# Step 8. Split train/test with 20% test, stratify, and seed = 2020.
#
# Step 9. Create a Random Forest with GridSearch on training data with 5 CV, scoring='f1-weighted',
# 	'criterion':['gini','entropy'],
# 'max_depth': [2,3],
# 'min_samples_leaf':[2,5],
# 'N_estimators':[100],
# 'random_state': 2020
#
# Step 10.  Predict the testing data set with classification_report.

# %% [markdown]
# **Complete class MushroomClassifier from given code template below.**

# %%
#import your other libraries here
import pandas as pd
# hint
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# import from sklearn.model_selection import train_test_split
# from sklearn.model_selection import ...
# from sklearn.ensemble import ...
# from sklearn.metrics import ...

# %%
import pandas as pd
# hint
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV

# sklearn_import for transform 
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline


class MushroomClassifier:
    def __init__(self, data_path): # DO NOT modify this line
        self.data_path = data_path
        self.df = pd.read_csv(data_path)

    def Q1(self): # DO NOT modify this line
        """
            1. (From step 1) Before doing the data prep., how many "na" are there in "gill-size" variables?
        """
      #  print(self.df['gill-size'].isna().sum())
    #    df_target_clean = self.df.dropna(subset = 'gill-size')
        # remove pass and replace with you code
        
        return int(self.df['gill-size'].isna().sum())


    def Q2(self): # DO NOT modify this line
        """
            2. (From step 2-4) How many rows of data, how many variables?
            - Drop rows where the target (label) variable is missing.
            - Drop the following variables:
            'id','gill-attachment', 'gill-spacing', 'gill-size','gill-color-rate','stalk-root', 'stalk-surface-above-ring',
            'stalk-surface-below-ring', 'stalk-color-above-ring-rate','stalk-color-below-ring-rate','veil-color-rate','veil-type'
            - Examine the number of rows, the number of digits, and whether any are missing.
        """
        df_target_clean = self.df.dropna(subset = 'label')
        df_target_clean = df_target_clean.drop( columns = ['id','gill-attachment', 'gill-spacing', 'gill-size','gill-color-rate','stalk-root', 'stalk-surface-above-ring',
            'stalk-surface-below-ring', 'stalk-color-above-ring-rate','stalk-color-below-ring-rate','veil-color-rate','veil-type'] )
        
        # remove pass and replace with you code
        return df_target_clean.shape


    def Q3(self): # DO NOT modify this line
        """
            3. (From step 5-6) Answer the quantity class0:class1
            - Fill missing values by adding the mean for numeric variables and the mode for nominal variables.
            - Convert the label variable e (edible) to 1 and p (poisonous) to 0 and check the quantity. class0: class1
            - Note: You need to reproduce the process (code) from Q2 to obtain the correct result.
        """

        # remove pass and replace with you code
        df_target_clean = self.df.dropna(subset = 'label')
        df_target_clean = df_target_clean.drop( columns = ['id','gill-attachment', 'gill-spacing', 'gill-size','gill-color-rate','stalk-root', 'stalk-surface-above-ring',
            'stalk-surface-below-ring', 'stalk-color-above-ring-rate','stalk-color-below-ring-rate','veil-color-rate','veil-type'] )

        for col in df_target_clean.columns : 
            if df_target_clean[col].dtype == 'object':
                df_target_clean[col] = df_target_clean[col].fillna(df_target_clean[col].mode()[0])
            else : 
                # check for numeric
                #filtered_loans_v1.fillna(filtered_loans_v1.mode().iloc[0], inplace=True)
                df_target_clean[col] = df_target_clean[col].fillna(df_target_clean[col].mean())
        # clean the data missing data type, now you can use the dummy code 
        df_target_clean['label'] = df_target_clean['label'].apply(lambda x: 1 if x == 'e' else  0  ) 
        
      #  print(df_target_clean.isnull().sum())
        # return class 0 : class 1
        return (df_target_clean['label']==0).sum(),   ( df_target_clean['label']==1).sum()
            

    def Q4(self): # DO NOT modify this line
        """
            4. (From step 7-8) How much is each training and testing sets
            - Convert the nominal variable to numeric using a dummy code with drop_first = True.
            - Split train/test with 20% test, stratify, and seed = 2020.
            - Note: You need to reproduce the process (code) from Q2, Q3 to obtain the correct result.
        """
        # remove pass and replace with you code
        df_target_clean = self.df.dropna(subset = 'label')
        df_target_clean = df_target_clean.drop( columns = ['id','gill-attachment', 'gill-spacing', 'gill-size','gill-color-rate','stalk-root', 'stalk-surface-above-ring',
            'stalk-surface-below-ring', 'stalk-color-above-ring-rate','stalk-color-below-ring-rate','veil-color-rate','veil-type'] )

        for col in df_target_clean.columns : 
            if df_target_clean[col].dtype == 'object':
                df_target_clean[col] = df_target_clean[col].fillna(df_target_clean[col].mode()[0])
            else : 
                # check for numeric
                #filtered_loans_v1.fillna(filtered_loans_v1.mode().iloc[0], inplace=True)
                df_target_clean[col] = df_target_clean[col].fillna(df_target_clean[col].mean())
        # clean the data missing data type, now you can use the dummy code 
        df_target_clean['label'] = df_target_clean['label'].apply(lambda x: 1 if x == 'e' else  0  ) 
        
    
        #print(df_target_clean.isna().sum())
        #print(df_target_clean)
        df_transform = pd.get_dummies(df_target_clean, drop_first=True).astype(int)

        Y = df_transform.pop('label')
        X = df_transform
        x_train, x_test, y_train, y_test = train_test_split(X, Y,test_size=0.2, stratify = Y, random_state = 2020)
        return x_train.shape, x_test.shape


    def Q5(self):
        """
            5. (From step 9) Best params after doing random forest grid search.
            Create a Random Forest with GridSearch on training data with 5 CV.
            - 'criterion':['gini','entropy']
            - 'max_depth': [2,3]
            - 'min_samples_leaf':[2,5]
            - 'N_estimators':[100]
            - 'random_state': 2020
            - Note: You need to reproduce the process (code) from Q2, Q3, Q4 to obtain the correct result.
        """
                # remove pass and replace with you code
        df_target_clean = self.df.dropna(subset = 'label')
        df_target_clean = df_target_clean.drop( columns = ['id','gill-attachment', 'gill-spacing', 'gill-size','gill-color-rate','stalk-root', 'stalk-surface-above-ring',
            'stalk-surface-below-ring', 'stalk-color-above-ring-rate','stalk-color-below-ring-rate','veil-color-rate','veil-type'] )

        for col in df_target_clean.columns : 
            if df_target_clean[col].dtype == 'object':
                df_target_clean[col] = df_target_clean[col].fillna(df_target_clean[col].mode()[0])
            else : 
                # check for numeric
                #filtered_loans_v1.fillna(filtered_loans_v1.mode().iloc[0], inplace=True)
                df_target_clean[col] = df_target_clean[col].fillna(df_target_clean[col].mean())
        # clean the data missing data type, now you can use the dummy code 
        df_target_clean['label'] = df_target_clean['label'].apply(lambda x: 1 if x == 'e' else  0  ) 
        
    
        #print(df_target_clean.isna().sum())
        #print(df_target_clean)
        df_transform = pd.get_dummies(df_target_clean, drop_first=True).astype(int)

        Y = df_transform.pop('label')
        X = df_transform
        x_train, x_test, y_train, y_test = train_test_split(X, Y,test_size=0.2, stratify = Y, random_state = 2020)

        grid_perms = {
            'criterion': ['gini', 'entropy'],
            'max_depth': [2, 3],
            'min_samples_leaf': [2, 5],
            'n_estimators': [100],
        }
        
        rf = RandomForestClassifier(random_state= 2020)
        
        gridsearch = GridSearchCV(
            estimator=rf,
            param_grid=grid_perms,
            cv=5,
            n_jobs=-1,
            scoring='f1_weighted'
        )
        
        gridsearch.fit(x_train, y_train)

        # remove pass and replace with you code
        best = gridsearch.best_params_

        return (
        best['criterion'],
        best['max_depth'],
        best['min_samples_leaf'],
        best['n_estimators'],
        2020  # random_state — fixed on the estimator, not part of best_params_
        )


    def Q6(self):
        """
            5. (From step 10) What is the value of macro f1 (2 digits)?
            Predict the testing data set with confusion_matrix and classification_report,
            using scientific rounding (less than 0.5 dropped, more than 0.5 then increased)
            - Note: You need to reproduce the process (code) from Q2, Q3, Q4, Q5 to obtain the correct result.
        """
        df_target_clean = self.df.dropna(subset = 'label')
        df_target_clean = df_target_clean.drop( columns = ['id','gill-attachment', 'gill-spacing', 'gill-size','gill-color-rate','stalk-root', 'stalk-surface-above-ring',
            'stalk-surface-below-ring', 'stalk-color-above-ring-rate','stalk-color-below-ring-rate','veil-color-rate','veil-type'] )

        for col in df_target_clean.columns : 
            if df_target_clean[col].dtype == 'object':
                df_target_clean[col] = df_target_clean[col].fillna(df_target_clean[col].mode()[0])
            else : 
                # check for numeric
                #filtered_loans_v1.fillna(filtered_loans_v1.mode().iloc[0], inplace=True)
                df_target_clean[col] = df_target_clean[col].fillna(df_target_clean[col].mean())
        # clean the data missing data type, now you can use the dummy code 
        df_target_clean['label'] = df_target_clean['label'].apply(lambda x: 1 if x == 'e' else  0  ) 
        
    
        #print(df_target_clean.isna().sum())
        #print(df_target_clean)
        df_transform = pd.get_dummies(df_target_clean, drop_first=True).astype(int)

        Y = df_transform.pop('label')
        X = df_transform
        x_train, x_test, y_train, y_test = train_test_split(X, Y,test_size=0.2, stratify = Y, random_state = 2020)

        grid_perms = {
            'criterion': ['gini', 'entropy'],
            'max_depth': [2, 3],
            'min_samples_leaf': [2, 5],
            'n_estimators': [100],
        }
        
        rf = RandomForestClassifier(random_state= 2020)
        
        gridsearch = GridSearchCV(
            estimator=rf,
            param_grid=grid_perms,
            cv=5,
            n_jobs=-1,
            scoring='f1_weighted'
        )
        
        gridsearch.fit(x_train, y_train)

        # remove pass and replace with you code
        best = gridsearch.best_params_

        
        predict = gridsearch.predict(x_test)

        report = classification_report(y_test, predict, output_dict=True)

        f1_class0 = round(report['0']['f1-score'], 2)
        f1_class1 = round(report['1']['f1-score'], 2)
        return f1_class0, f1_class1

# %% [markdown]
# Run the code below to test that your code can work.

# %%
hw = MushroomClassifier('mushroom2020_dataset.csv')

print(hw.Q1())
print(hw.Q2())
print(hw.Q3())
print(hw.Q4())
print(hw.Q5())
print(hw.Q6())
# Out:
# 121
# (5764, 12)
# (3660, 2104)
# ((4611, 42), (1153, 42))
# C:\Users\Krisda Taveesak\AppData\Local\Temp\ipykernel_43440\2659259960.py:62: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_target_clean[col].fillna(df_target_clean[col].mode()[0], inplace=True)
# C:\Users\Krisda Taveesak\AppData\Local\Temp\ipykernel_43440\2659259960.py:66: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_target_clean[col].fillna(df_target_clean[col].mean(), inplace = True )
# C:\Users\Krisda Taveesak\AppData\Local\Temp\ipykernel_43440\2659259960.py:89: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_target_clean[col].fillna(df_target_clean[col].mode()[0], inplace=True)
# C:\Users\Krisda Taveesak\AppData\Local\Temp\ipykernel_43440\2659259960.py:93: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_target_clean[col].fillna(df_target_clean[col].mean(), inplace = True )
# C:\Users\Krisda Taveesak\AppData\Local\Temp\ipykernel_43440\2659259960.py:126: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_target_clean[col].fillna(df_target_clean[col].mode()[0], inplace=True)
# C:\Users\Krisda Taveesak\AppData\Local\Temp\ipykernel_43440\2659259960.py:130: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_target_clean[col].fillna(df_target_clean[col].mean(), inplace = True )
# ('gini', 3, 2, 100, 2020)
# C:\Users\Krisda Taveesak\AppData\Local\Temp\ipykernel_43440\2659259960.py:187: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_target_clean[col].fillna(df_target_clean[col].mode()[0], inplace=True)
# C:\Users\Krisda Taveesak\AppData\Local\Temp\ipykernel_43440\2659259960.py:191: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_target_clean[col].fillna(df_target_clean[col].mean(), inplace = True )
# (0.98, 0.97)
